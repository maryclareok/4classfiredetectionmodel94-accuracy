# %% [markdown]
# <a href="https://colab.research.google.com/github/maryclareok/4classfiredetectionmodel94-accuracy/blob/main/fire%2Csmoke%2Cfireandsmoke%2Cnonfireandsmokedetection02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
import os
import numpy as np

# Define directories
base_dir = '/content/drive/MyDrive/work/training'
classes = ['fire', 'fire and smoke', 'neither', 'smoke']

# Preprocess the data
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    classes=classes,
    subset='training')

validation_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    classes=classes,
    subset='validation')
# Out:
# Found 965 images belonging to 4 classes.
# Found 239 images belonging to 4 classes.

# %%
# @title
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

train_generator = datagen.flow_from_directory(
    base_dir,
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical',
    classes=classes)

# Define the model
model_12 = Sequential()
model_12.add(Conv2D(32, (5, 5), activation='relu', input_shape=(64, 64, 3)))
model_12.add(MaxPooling2D(pool_size=(2, 2)))
model_12.add(Conv2D(64, (4, 4), activation='relu'))
model_12.add(MaxPooling2D(pool_size=(2, 2)))
model_12.add(Flatten())
model_12.add(Dense(100))
# model.add(Dense(64, activation='tanh'))  # 'tanh' activation
# model.add(Dropout(0.5))
model_12.add(Dense(128, activation='relu'))
model_12.add(Dense(4, activation='softmax'))

# Compile the model
model_12.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model_12.fit(train_generator, epochs=200, validation_data=validation_generator)
# Out:
# Found 1204 images belonging to 4 classes.
# Epoch 1/200
# 38/38 [==============================] - 22s 543ms/step - loss: 1.2525 - accuracy: 0.3812 - val_loss: 1.0728 - val_accuracy: 0.5230
# Epoch 2/200
# 38/38 [==============================] - 19s 509ms/step - loss: 1.1221 - accuracy: 0.4792 - val_loss: 1.0584 - val_accuracy: 0.5858
# Epoch 3/200
# 38/38 [==============================] - 19s 500ms/step - loss: 1.0562 - accuracy: 0.5349 - val_loss: 1.0031 - val_accuracy: 0.6151
# Epoch 4/200
# 38/38 [==============================] - 21s 546ms/step - loss: 1.0146 - accuracy: 0.5440 - val_loss: 1.0131 - val_accuracy: 0.5900
# Epoch 5/200
# 38/38 [==============================] - 19s 513ms/step - loss: 1.0038 - accuracy: 0.5847 - val_loss: 1.0407 - val_accuracy: 0.5397
# Epoch 6/200
# 38/38 [==============================] - 19s 506ms/step - loss: 0.9660 - accuracy: 0.5922 - val_loss: 0.9510 - val_accuracy: 0.6234
# Epoch 7/200
# 38/38 [==============================] - 20s 537ms/step - loss: 0.9569 - accuracy: 0.5939 - val_loss: 0.9790 - val_accuracy: 0.6444
# Epoch 8/200
# 38/38 [==============================] - 20s 522ms/step - loss: 0.9400 - accuracy: 0.6080 - val_loss: 0.9428 - val_accuracy: 0.6611
# Epoch 9/200
# 38/38 [==============================] - 19s 493ms/step - loss: 0.9215 - accuracy: 0.6146 - val_loss: 0.9036 - val_accuracy: 0.6485
# Epoch 10/200
# 38/38 [==============================] - 20s 531ms/step - loss: 0.8910 - accuracy: 0.6346 - val_loss: 0.8846 - val_accuracy: 0.6695
# Epoch 11/200
# 38/38 [==============================] - 20s 520ms/step - loss: 0.8642 - accuracy: 0.6395 - val_loss: 0.9214 - val_accuracy: 0.6527
# Epoch 12/200
# 38/38 [==============================] - 19s 504ms/step - loss: 0.8505 - accuracy: 0.6628 - val_loss: 0.9852 - val_accuracy: 0.6067
# Epoch 13/200
200
# 38/38 [==============================] - 18s 482ms/step - loss: 0.2268 - accuracy: 0.9103 - val_loss: 0.1916 - val_accuracy: 0.9163
# Epoch 161/200
# 38/38 [==============================] - 20s 518ms/step - loss: 0.1868 - accuracy: 0.9236 - val_loss: 0.1922 - val_accuracy: 0.9121
# Epoch 162/200
# 38/38 [==============================] - 18s 476ms/step - loss: 0.2321 - accuracy: 0.9236 - val_loss: 0.1654 - val_accuracy: 0.9247
# Epoch 163/200
# 38/38 [==============================] - 18s 482ms/step - loss: 0.2141 - accuracy: 0.9236 - val_loss: 0.1596 - val_accuracy: 0.9372
# Epoch 164/200
# 38/38 [==============================] - 19s 514ms/step - loss: 0.2342 - accuracy: 0.9095 - val_loss: 0.3612 - val_accuracy: 0.8661
# Epoch 165/200
# 38/38 [==============================] - 18s 480ms/step - loss: 0.2222 - accuracy: 0.9153 - val_loss: 0.1246 - val_accuracy: 0.9540
# Epoch 166/200
# 38/38 [==============================] - 18s 466ms/step - loss: 0.2108 - accuracy: 0.9120 - val_loss: 0.1113 - val_accuracy: 0.9414
# Epoch 167/200
# 38/38 [==============================] - 18s 483ms/step - loss: 0.2244 - accuracy: 0.9136 - val_loss: 0.1207 - val_accuracy: 0.9456
# Epoch 168/200
# 38/38 [==============================] - 18s 477ms/step - loss: 0.2112 - accuracy: 0.9261 - val_loss: 0.1343 - val_accuracy: 0.9498
# Epoch 169/200
# 38/38 [==============================] - 18s 487ms/step - loss: 0.1923 - accuracy: 0.9194 - val_loss: 0.1289 - val_accuracy: 0.9414
# Epoch 170/200
# 38/38 [==============================] - 18s 463ms/step - loss: 0.2125 - accuracy: 0.9219 - val_loss: 0.1494 - val_accuracy: 0.9372
# Epoch 171/200
# 38/38 [==============================] - 20s 524ms/step - loss: 0.2292 - accuracy: 0.9169 - val_loss: 0.1668 - val_accuracy: 0.9372
# Epoch 172/200
# 38/38 [==============================] - 18s 482ms/step - loss: 0.2536 - accuracy: 0.9070 - val_loss: 0.2186 - val_accuracy: 0.9205
# Epoch 173/200
# 38/38 [==============================] - 18s 489ms/step - loss: 0.2541 - accuracy: 0.9086 - val_loss: 0.1856 - val_accuracy: 0.9331
# Epoch 174/200
# 38/38 [==============================] - 19s 506ms/step - loss: 0.2112 - accuracy: 0.9194 - val_loss: 0.1858 - val_accuracy: 0.9247
# Epoch 175/200
# 38/38 [==============================] - 18s 491ms/step - loss: 0.2320 - accuracy: 0.9128 - val_loss: 0.1225 - val_accuracy: 0.9582
# Epoch 176/200
# 38/38 [==============================] - 19s 507ms/step - loss: 0.1812 - accuracy: 0.9286 - val_loss: 0.1107 - val_accuracy: 0.9582
# Epoch 177/200
# 38/38 [==============================] - 19s 500ms/step - loss: 0.1592 - accuracy: 0.9394 - val_loss: 0.1328 - val_accuracy: 0.9498
# Epoch 178/200
# 38/38 [==============================] - 18s 473ms/step - loss: 0.1615 - accuracy: 0.9419 - val_loss: 0.0718 - val_accuracy: 0.9791
# Epoch 179/200
# 38/38 [==============================] - 19s 496ms/step - loss: 0.1843 - accuracy: 0.9319 - val_loss: 0.1236 - val_accuracy: 0.9540
# Epoch 180/200
# 38/38 [==============================] - 18s 476ms/step - loss: 0.1457 - accuracy: 0.9477 - val_loss: 0.1527 - val_accuracy: 0.9540
# Epoch 181/200
# 38/38 [==============================] - 20s 524ms/step - loss: 0.2249 - accuracy: 0.9153 - val_loss: 0.1282 - val_accuracy: 0.9498
# Epoch 182/200
# 38/38 [==============================] - 18s 478ms/step - loss: 0.1969 - accuracy: 0.9236 - val_loss: 0.1321 - val_accuracy: 0.9498
# Epoch 183/200
# 38/38 [==============================] - 18s 482ms/step - loss: 0.2512 - accuracy: 0.9145 - val_loss: 0.1415 - val_accuracy: 0.9623
# Epoch 184/200
# 38/38 [==============================] - 18s 476ms/step - loss: 0.1982 - accuracy: 0.9203 - val_loss: 0.1809 - val_accuracy: 0.9289
# Epoch 185/200
# 38/38 [==============================] - 18s 485ms/step - loss: 0.1688 - accuracy: 0.9385 - val_loss: 0.1268 - val_accuracy: 0.9582
# Epoch 186/200
# 38/38 [==============================] - 18s 485ms/step - loss: 0.1699 - accuracy: 0.9344 - val_loss: 0.0895 - val_accuracy: 0.9582
# Epoch 187/200
# 38/38 [==============================] - 18s 481ms/step - loss: 0.1705 - accuracy: 0.9410 - val_loss: 0.1736 - val_accuracy: 0.9540
# Epoch 188/200
# 38/38 [==============================] - 19s 514ms/step - loss: 0.2371 - accuracy: 0.9111 - val_loss: 0.1259 - val_accuracy: 0.9456
# Epoch 189/200
# 38/38 [==============================] - 18s 479ms/step - loss: 0.2310 - accuracy: 0.9128 - val_loss: 0.2204 - val_accuracy: 0.8870
# Epoch 190/200
# 38/38 [==============================] - 20s 516ms/step - loss: 0.1940 - accuracy: 0.9261 - val_loss: 0.1089 - val_accuracy: 0.9582
# Epoch 191/200
# 38/38 [==============================] - 18s 455ms/step - loss: 0.1733 - accuracy: 0.9311 - val_loss: 0.1314 - val_accuracy: 0.9498
# Epoch 192/200
# 38/38 [==============================] - 18s 483ms/step - loss: 0.1809 - accuracy: 0.9369 - val_loss: 0.1789 - val_accuracy: 0.9289
# Epoch 193/200
# 38/38 [==============================] - 19s 494ms/step - loss: 0.2306 - accuracy: 0.9277 - val_loss: 0.2524 - val_accuracy: 0.9247
# Epoch 194/200
# 38/38 [==============================] - 18s 488ms/step - loss: 0.2066 - accuracy: 0.9219 - val_loss: 0.2406 - val_accuracy: 0.9205
# Epoch 195/200
# 38/38 [==============================] - 18s 479ms/step - loss: 0.2710 - accuracy: 0.9169 - val_loss: 0.1700 - val_accuracy: 0.9372
# Epoch 196/200
# 38/38 [==============================] - 18s 481ms/step - loss: 0.2237 - accuracy: 0.9136 - val_loss: 0.1510 - val_accuracy: 0.9456
# Epoch 197/200
# 38/38 [==============================] - 18s 469ms/step - loss: 0.2330 - accuracy: 0.9203 - val_loss: 0.1059 - val_accuracy: 0.9540
# Epoch 198/200
# 38/38 [==============================] - 19s 510ms/step - loss: 0.1934 - accuracy: 0.9302 - val_loss: 0.1288 - val_accuracy: 0.9582
# Epoch 199/200
# 38/38 [==============================] - 18s 458ms/step - loss: 0.1515 - accuracy: 0.9444 - val_loss: 0.2350 - val_accuracy: 0.9163
# Epoch 200/200
# 38/38 [==============================] - 18s 482ms/step - loss: 0.1533 - accuracy: 0.9427 - val_loss: 0.1402 - val_accuracy: 0.9414

# %%
# Save the entire model as a SavedModel.
model_12.save('my_model90%accuracy')

# The model is saved to the disk at the specified location ('my_model' in this case)
# and can be loaded later using the `load_model` function.

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# Predict the classes
pred = model_12.predict(validation_generator, verbose=1)
predicted_classes = np.argmax(pred, axis=1)

# Get the confusion matrix
cm = confusion_matrix(validation_generator.classes, predicted_classes)

# Plot the confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt="d")
plt.title("Confusion matrix")
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Get the ROC curve
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(len(classes)):
    try:
        fpr[i], tpr[i], _ = roc_curve(validation_generator.classes == i, pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    except ValueError:
        print(f"ROC curve computation failed for class {i}. Continuing with next class...")
        continue

# Plot the ROC curve
for i in range(len(classes)):
    if i in fpr:
        plt.figure()
        plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f)' % roc_auc[i])
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic for '+classes[i])
        plt.legend(loc="lower right")
        plt.show()
# Out:
# 8/8 [==============================] - 4s 398ms/step

# %%
# Evaluate the model
eval_result = model_12.evaluate(validation_generator)
print(f'Test loss: {eval_result[0]}, Test accuracy: {eval_result[1]}')
# Out:
# 8/8 [==============================] - 5s 616ms/step - loss: 0.1402 - accuracy: 0.9414
# Test loss: 0.14016836881637573, Test accuracy: 0.9414225816726685

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

# Predict a single image
img_path = '/content/drive/MyDrive/work/test7.jpg'  # replace with your image path
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(64, 64))
img_array = tf.keras.preprocessing.image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = img_batch/255.
prediction = model_12.predict(img_preprocessed)

# Get the class with the highest probability
predicted_class_index = np.argmax(prediction)
predicted_class = classes[predicted_class_index]

print(f'The model predicts that the image is of class: {predicted_class}')

# Display the image
plt.imshow(img)
plt.title(f'Predicted class: {predicted_class}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 17ms/step
# The model predicts that the image is of class: fire

# %%
from tensorflow.keras.utils import plot_model

# Plot the model
plot_model(model_12, to_file='model.png', show_shapes=True, show_layer_names=True)

# %%
from tensorflow.keras import metrics
from sklearn.metrics import classification_report
import numpy as np

# Predict the classes
validation_steps_per_epoch = np.math.ceil(validation_generator.samples / validation_generator.batch_size)
predictions = model_12.predict(validation_generator, steps=validation_steps_per_epoch)
predicted_classes = np.argmax(predictions, axis=1)

# Get the true classes
true_classes = validation_generator.classes

# Get the classification report
report = classification_report(true_classes, predicted_classes, target_names=list(validation_generator.class_indices.keys()))
print(report)

# Calculate AUC
auc = metrics.AUC()
auc.update_state(true_classes, predicted_classes)
print('AUC: ', auc.result().numpy())
# Out:
# 8/8 [==============================] - 4s 388ms/step
#                 precision    recall  f1-score   support
#
#           fire       0.29      0.30      0.29        61
# fire and smoke       0.30      0.29      0.30        59
#        neither       0.32      0.37      0.35        59
#          smoke       0.28      0.25      0.27        60
#
#       accuracy                           0.30       239
#      macro avg       0.30      0.30      0.30       239
#   weighted avg       0.30      0.30      0.30       239
#
# AUC:  0.52394545
